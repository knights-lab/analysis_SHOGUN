# %%
import pandas as pd

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="be888973-57c4-4430-bc0b-8aaa9ef9412a">Loading BokehJS ...</span>
#     </div>

# %%
df_rep82 = pd.read_csv("./../data/references/rep82/utree/rep82.gg.log", sep="\t", header=None, index_col=0)
df_rep82_dusted = pd.read_csv("./../data/references/rep82_dusted/utree/rep82_dusted.gg.log", sep="\t", header=None, index_col=0)

# %%
for df in (df_rep82, df_rep82_dusted):
    df["level"] = [_.count(";") + 1 for _ in df.index]

# %%
from bokeh.charts import Histogram
hist = Histogram(list(df_rep82['level']), title="Taxonomic Levels", bins=3)
hist2 = Histogram(list(df_rep82_dusted['level']), title="Taxonomic Levels", bins=3)

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="13fb5a57-afbc-4022-8db6-94d8e2cdba4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("13fb5a57-afbc-4022-8db6-94d8e2cdba4a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13fb5a57-afbc-4022-8db6-94d8e2cdba4a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13fb5a57-afbc-4022-8db6-94d8e2cdba4a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6f1279a5-c8d6-4257-8dde-2c017ca71c49":{"roots":{"references":[{"attributes":{},"id":"3dd9e1a3-2f36-4641-b812-8d779cca02af","type":"LinearScale"},{"attributes":{},"id":"e858c36a-c697-431c-b9d6-7dc8b184bb1f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":16018.2},"id":"2a16e53a-336b-45c8-acca-6d1fc969e341","type":"Range1d"},{"attributes":{"overlay":{"id":"15e8f1f7-4097-4340-8cf9-fd7b7f4271fe","type":"BoxAnnotation"},"plot":{"id":"6c396579-8187-4df0-834a-e8e609c55b84","subtype":"Chart","type":"Plot"}},"id":"611c1851-7726-4ca7-8794-35650f7fb5cb","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6c396579-8187-4df0-834a-e8e609c55b84","subtype":"Chart","type":"Plot"},"ticker":{"id":"2c66395d-fd09-4500-9328-5aedace535da","type":"BasicTicker"}},"id":"4586aade-0494-40fa-a364-01296790d9bf","type":"Grid"},{"attributes":{"data_source":{"id":"32a2888b-d06d-4b63-b4b5-0e985a0b8a08","type":"ColumnDataSource"},"glyph":{"id":"1f32ff6d-58c9-459d-bbd9-3ad9831b7139","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a45d8411-1c87-4b8c-b1f6-b21c8964d091","type":"GlyphRenderer"},{"attributes":{},"id":"ac8bd3f8-8cd5-4308-b095-116174865f73","type":"LinearScale"},{"attributes":{"plot":{"id":"6c396579-8187-4df0-834a-e8e609c55b84","subtype":"Chart","type":"Plot"}},"id":"78b4d228-1fd4-4347-9241-15df1522b092","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Taxonomic Levels"},"id":"c428cda4-053b-4ce5-b4fa-93f56127549d","type":"Title"},{"attributes":{},"id":"2f33c62f-a1cd-4bd8-b503-a7cfb9398f29","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c0e3ef56-559c-4b0a-9358-811c52fd10cd","type":"PanTool"},{"id":"78b4d228-1fd4-4347-9241-15df1522b092","type":"WheelZoomTool"},{"id":"611c1851-7726-4ca7-8794-35650f7fb5cb","type":"BoxZoomTool"},{"id":"832834d4-c5a7-4d89-b335-69e3558f2f4c","type":"SaveTool"},{"id":"d6204075-f2d7-4e91-8c6f-1235cf2bf374","type":"ResetTool"},{"id":"0aa9787d-dfec-441f-bfcf-20cfad6bcc2a","type":"HelpTool"}]},"id":"2caccbc1-501e-40b5-9f70-ffbf7b239945","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["label","line_alpha","line_color","height","color","x","fill_alpha","width","y"],"data":{"chart_index":["(5.666667, 8.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14562.0],"label":["(5.666667, 8.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.333333333333333],"x":["6.8333335"],"y":[7281.0]}},"id":"32a2888b-d06d-4b63-b4b5-0e985a0b8a08","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"994e916d-2ec5-4534-8b20-2421e85a7a89","type":"Rect"},{"attributes":{"plot":{"id":"6c396579-8187-4df0-834a-e8e609c55b84","subtype":"Chart","type":"Plot"}},"id":"c0e3ef56-559c-4b0a-9358-811c52fd10cd","type":"PanTool"},{"attributes":{"data_source":{"id":"b91174f7-0213-4331-a902-31b12b365a4f","type":"ColumnDataSource"},"glyph":{"id":"994e916d-2ec5-4534-8b20-2421e85a7a89","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"700ead58-d89c-494a-8389-a20ee01dfaff","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":8.225000166666666,"start":0.7749998333333331},"id":"c97d41e8-832d-47fe-a94a-61e9c35fdefc","type":"Range1d"},{"attributes":{"location":"top_left","plot":{"id":"6c396579-8187-4df0-834a-e8e609c55b84","subtype":"Chart","type":"Plot"}},"id":"0e0de3c3-e758-432f-9023-4e604c054e01","type":"Legend"},{"attributes":{},"id":"ceb2b48b-727e-4ab1-808a-b70f3a9cb0b7","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id ...

# %%
show(hist2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5f1de559-643b-4885-9fb9-f08b4bffb75d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5f1de559-643b-4885-9fb9-f08b4bffb75d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5f1de559-643b-4885-9fb9-f08b4bffb75d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5f1de559-643b-4885-9fb9-f08b4bffb75d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ec537f36-cd40-4286-a093-4e716636bd4d":{"roots":{"references":[{"attributes":{},"id":"b2d4ccb8-8dea-489c-be25-e2b5f61b9797","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"40018811-e227-4d1b-bb2e-7f9ea8324897","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["label","line_alpha","line_color","height","color","x","fill_alpha","width","y"],"data":{"chart_index":["(5.666667, 8.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14554.0],"label":["(5.666667, 8.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.333333333333333],"x":["6.8333335"],"y":[7277.0]}},"id":"0b26f9e6-054a-47d5-982c-921e55ae3688","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ace23206-e3de-497b-aafe-0c401ca099b3","type":"ColumnDataSource"},"glyph":{"id":"1e8f649a-a91f-4fce-b0ee-7dd31b916a8f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b756b2e5-9af9-477c-a9d4-a12c284c71bc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0b26f9e6-054a-47d5-982c-921e55ae3688","type":"ColumnDataSource"},"glyph":{"id":"9ea7b8b9-c8aa-4e1f-a6b8-87c8f1011326","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1b977e10-a613-4eef-97b3-be3127d236c7","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"47d66648-88b1-490e-a819-16b1d99eb720","type":"Rect"},{"attributes":{"axis_label":"a","formatter":{"id":"b2d4ccb8-8dea-489c-be25-e2b5f61b9797","type":"BasicTickFormatter"},"plot":{"id":"5ec38a35-2308-4a24-b3c4-9be2d25b90e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"aaa4913b-3b4b-48ef-97c9-7d69cdf563a9","type":"BasicTicker"}},"id":"fdf4e3f0-3c3d-4043-87a0-48a65c2e0a13","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["label","line_alpha","line_color","height","color","x","fill_alpha","width","y"],"data":{"chart_index":["[1.000000, 3.333333]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["[1.000000, 3.333333]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.3333333333333335],"x":["2.1666665"],"y":[0.5]}},"id":"572931fc-2c33-4555-bcfa-653673e7f395","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"40018811-e227-4d1b-bb2e-7f9ea8324897","type":"BoxAnnotation"},"plot":{"id":"5ec38a35-2308-4a24-b3c4-9be2d25b90e2","subtype":"Chart","type":"Plot"}},"id":"dca6f7c3-890a-48dc-a54e-92ca08782f7c","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":16009.400000000001},"id":"ce98cbc9-bb76-4c55-b6d1-85a6a7331f71","type":"Range1d"},{"attributes":{},"id":"60015249-f17a-4d34-b384-27b82a7d8a9d","type":"LinearScale"},{"attributes":{"location":"top_left","plot":{"id":"5ec38a35-2308-4a24-b3c4-9be2d25b90e2","subtype":"Chart","type":"Plot"}},"id":"773403fd-78c5-4f51-8653-5b28515e081f","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ea7b8b9-c8aa-4e1f-a6b8-87c8f1011326","type":"Rect"},{"attributes":{"data_source":{"id":"572931fc-2c33-4555-bcfa-653673e7f395","type":"ColumnDataSource"},"glyph":{"id":"47d66648-88b1-490e-a819-16b1d99eb720","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f84d9ec8-1d44-4e07-82d4-b20807f6ebb8","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"5ec38a35-2308-4a24-b3c4-9be2d25b90e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"6333d4a6-f479-433c-819e-cd ...

# %%
# Only two levels? Is the log being output correctly?
print(df_rep82["level"].unique())
print(df_rep82_dusted["level"].unique())
# Out:
# [8 1]
# [8 1]

# %%
levels.unique()
# Out:
# array([8, 1])
